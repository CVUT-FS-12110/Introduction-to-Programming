# %% [markdown]
# # Úkoly na cvičení: Volební algoritmy
#
# Každý úkol má svoji kostru, kterou je třeba doplnit. Vždy spusťte kontrolní buňku pod úkolem, aby se oveřilo, že dáváte správné výsledky.

# %%
# Inicializace dat (spusť tohle jako první!)
volby_2021 = {
    "SPOLU": 1493905,
    "ANO": 1458140,
    "Piráti+STAN": 839776,
    "SPD": 513910
}
CELKEM_MANDATU = 200

# %% [markdown]
# ## Úkol 1: Implementace D'Hondtovy metody (★★☆)
#
# Vaším úkolem je naprogramovat `dhondt` funkci. Vstupem je slovník s výsledky a počet mandátů k rozdělení. Výstupem musí být slovník, kolik kdo dostal křesel.

# %%
def dhondt(hlasy, pocet_mandatu):
    # KROK 1: Vytvoř prázdný slovník a dej všem na začátku 0 mandátů
    mandaty = ...
    
    # KROK 2: Loop přes pocet_mandatu
    # V každém kroku musíš projít strany z 'hlasy' a spočítat jim aktuální kvocient.
    # Kvocient = pocet_hlasu / (zatim_ziskano_mandatu + 1)
    
    # Vítězné straně v daném kole mandát přičti
    
    return mandaty

# %%
# KONTROLNÍ BUŇKA (Sama by měla hodit správný výsledek = SPOLU: 71, ANO: 72, Piráti: 37, SPD: 20)
vysledek = dhondt(volby_2021, CELKEM_MANDATU)
print(vysledek)

# %% [markdown]
# ## Úkol 2: Sainte-Laguë metoda (★★★)
#
# Co kdybychom nedělili 1, 2, 3, 4..., ale místo toho lichými čísly 1, 3, 5, 7...? To přesně zkouší spravedlivější `Sainte-Laguë` metoda. Zkopírujte tělo vaší funkce `dhondt` a upravte jmenovatel.

# %%
def sainte_lague(hlasy, pocet_mandatu):
    # KROK 1: Místo '(zatim_ziskano_mandatu + 1)'
    # pouzij vzorec pro liché číslo nth terminu: '(2 * zatim_ziskano_mandatu + 1)'
    pass

# %%
# KONTROLNÍ BUŇKA pro Sainte-Laguë. Výsledek by se měl mírně lišit ve prospěch menších stran.
vysledek = sainte_lague(volby_2021, CELKEM_MANDATU)
print(vysledek)

# %% [markdown]
# ## Úkol 3: Slepý experiment klauzule (★★★☆)
#
# Ověřte si tezi o propadlých hlasech. Dáme Vám teď seznam VŠECH stran z roku 2021. Spočítejte co by se stalo, kdyby nebyla žádná klauzule (0 %). Vytiskněte jen strany, které mandát nakonec dostanou přes D'Hondta.

# %%
# Plná data s neúspěšnými stranami
volby_2021_vsechny = {
    "SPOLU": 1493905, "ANO": 1458140, "Piráti+STAN": 839776, "SPD": 513910, 
    "Přísaha": 251562, "ČSSD": 250397, "KSČM": 193817, "Trikolora": 149720, "Zelení": 53583
}

# Tady spusť dhondta a ukaž výsledek bez klauzule. Kdo ztratí kolik křesel ku prospěchu menších stran?
